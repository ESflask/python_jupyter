# %%
import numpy as np
import pandas as pd
dic = {'a': ['Tokyo','Kanagawa','Chiba'],'b':['Saitama','Tochigi','Ibaraki']}
pd.DataFrame(dic)
# Out:
#           a        b
# 0     Tokyo  Saitama
# 1  Kanagawa  Tochigi
# 2     Chiba  Ibaraki

# %%
import numpy as np
import pandas as pd 
mix_dic = {'a':[1,2,3],'b':['a','b','c'],'c':(4,5,6)}
pd.DataFrame(mix_dic)
# Out:
#    a  b  c
# 0  1  a  4
# 1  2  b  5
# 2  3  c  6

# %%
import numpy as np
import pandas as pd
arr_np = np.array([[12,34,56],[78,90,12]])
pd.DataFrame(arr_np)
# Out:
#     0   1   2
# 0  12  34  56
# 1  78  90  12

# %%
import numpy as np
import pandas as pd
state = pd.Series(["Tokyo","Osaka","Aichi","Hiroshima","Fukuoka"])
population = pd.Series([13515,8839,3060,1209,5102])
num_household = pd.Series([6691,3918,3060,1209,2197])

satistic = pd.DataFrame({
    "state" : state,
    "population" : population,
    "num_household" : num_household
})

satistic
# Out:
#        state  population  num_household
# 0      Tokyo       13515           6691
# 1      Osaka        8839           3918
# 2      Aichi        3060           3060
# 3  Hiroshima        1209           1209
# 4    Fukuoka        5102           2197

# %%
static_dict = {
    "population" : {
        "Tokyo" : 13515,
        "Osaka" : 8839,
        "Aichi" : 7483,
        "Hiroshima" : 2844,
        "Fukuoka" : 5102
    },
    "num_household" : {
        "Osaka" : 3918,
        "Aichi" : 3060,
        "Tokyo" : 6691,
        "Hiroshima" : 1209,
        "Fukuoka" : 2197
    }
}
statistic_2 = pd.DataFrame(static_dict)
statistic_2
# Out:
#            population  num_household
# Tokyo           13515           6691
# Osaka            8839           3918
# Aichi            7483           3060
# Hiroshima        2844           1209
# Fukuoka          5102           2197

# %%
statistic_3 = statistic_2.T
statistic_3     # 転置
# Out:
#                Tokyo  Osaka  Aichi  Hiroshima  Fukuoka
# population     13515   8839   7483       2844     5102
# num_household   6691   3918   3060       1209     2197

# %%
statistic_3['Hokkaido'] = [5506,2438]
statistic_3    # 新しいデータの追加
# Out:
#                Tokyo  Osaka  Aichi  Hiroshima  Fukuoka  Hokkaido
# population     13515   8839   7483       2844     5102      5506
# num_household   6691   3918   3060       1209     2197      2438

# %%
del statistic_3['Hokkaido'] # データの削除"del"
statistic_3
# Out:
#                Tokyo  Osaka  Aichi  Hiroshima  Fukuoka
# population     13515   8839   7483       2844     5102
# num_household   6691   3918   3060       1209     2197

# %%
statistic_3.loc['population','Fukuoka']
statistic_3.iloc[1,3]
# Out:
# np.int64(1209)

# %%
import numpy as np
import pandas as pd
df = pd.read_csv('weather.csv',sep=',')
print('df.shape:',df.shape) #行列の大きさ
print()
print('df.index:', df.index) #行のインデックス
print('df.columns:',df.columns) #データラベル
print()
print('df.dtypes:\n', df.dtypes)    #データの型
# Out:
# df.shape: (92, 10)
#
# df.index: RangeIndex(start=0, stop=92, step=1)
# df.columns: Index(['date', 'ave_temperature', 'max_temperature', 'min_temperature',
#        'precipitation', 'daylight_hours', 'cloud_amount', 'ave_wind_speed',
#        'max_wind_speed', 'max_wind_direction'],
#       dtype='str')
#
# df.dtypes:
#  date                      str
# ave_temperature       float64
# max_temperature       float64
# min_temperature       float64
# precipitation         float64
# daylight_hours        float64
# cloud_amount          float64
# ave_wind_speed        float64
# max_wind_speed        float64
# max_wind_direction        str
# dtype: object

# %%
import numpy as np
import pandas as pd
df = pd.read_csv('weather.csv',sep=',')
df[['date','ave_temperature']].head()
df[50:55]
# Out:
#          date  ave_temperature  max_temperature  min_temperature  \
# 50  2019/4/20             14.2             19.1              9.8
# 51  2019/4/21             17.5             23.1             12.2
# 52  2019/4/22             19.2             25.6             14.4
# 53  2019/4/23             18.7             23.3             15.3
# 54  2019/4/24             19.1             20.6             17.5
#
#     precipitation  daylight_hours  cloud_amount  ave_wind_speed  \
# 50            NaN            11.3           5.3             3.7
# 51            NaN             7.9           8.0             2.3
# 52            0.0             8.9           9.0             2.6
# 53            0.0             7.3          10.0             3.3
# 54            3.0             0.0          10.0             4.5
#
#     max_wind_speed max_wind_direction
# 50             6.9                 南東
# 51             6.3                 南東
# 52             6.5                南南東
# ...

# %%
import numpy as np
import pandas as pd
df = pd.read_csv('weather.csv',sep=',')
df.loc[50]  #50行目のデータを"指定して"表示可能
# Out:
# date                  2019/4/20
# ave_temperature            14.2
# max_temperature            19.1
# min_temperature             9.8
# precipitation               NaN
# daylight_hours             11.3
# cloud_amount                5.3
# ave_wind_speed              3.7
# max_wind_speed              6.9
# max_wind_direction           南東
# Name: 50, dtype: object

# %%
import numpy as np
import pandas as pd
df = pd.read_csv('weather.csv',sep=',')
df.iloc[[0,31,61],[0,1,2,3]]
# Out:
#         date  ave_temperature  max_temperature  min_temperature
# 0   2019/3/1              8.8             13.1              6.5
# 31  2019/4/1              8.8             16.2              4.2
# 61  2019/5/1             17.4             23.4             14.3

# %%
import numpy as np
import pandas as pd
df = pd.read_csv('weather.csv',sep=',')
df[['date', 'max_temperature', 'max_wind_direction']].query('max_temperature < 10 and max_wind_direction == "北西"')    # 北西のデータだけ提示
# Out:
#          date  max_temperature max_wind_direction
# 3    2019/3/4              9.5                 北西
# 22  2019/3/23              9.0                 北西

# %%
import numpy as np
import pandas as pd
df = pd.read_csv('weather.csv',sep=',')
df['max_wind_direction'].unique()   # unique() ... データ一覧
# Out:
# <StringArray>
# ['北西', '北北西', '南南東', '南', '南西', '南東', '西北西', '南南西', '東北東', '西南西', '東南東', '北東']
# Length: 12, dtype: str

# %%
import numpy as np
import pandas as pd
df = pd.read_csv('weather.csv',sep=',')

print(len(df)) == len(df['date'].unique())
print(len(df)) == len(df['daylight_hours'].unique())
# Out:
# 92
# 92
# False

# %%
import numpy as np
import pandas as pd
df = pd.read_csv('weather.csv',sep=',')

print(df["precipitation"].sum())
print(df["precipitation"].mean())
# Out:
# 328.5
# 6.3173076923076925

# %%
df.describe()
# Out:
#        ave_temperature  max_temperature  min_temperature  precipitation  \
# count        92.000000        92.000000        92.000000      52.000000
# mean         14.743478        19.902174        10.220652       6.317308
# std           5.037667         5.506320         5.021044      13.823477
# min           5.700000         9.000000         1.100000       0.000000
# 25%          10.150000        15.700000         5.975000       0.000000
# 50%          15.150000        19.900000         9.750000       0.250000
# 75%          18.725000        23.900000        14.425000       5.125000
# max          26.100000        32.600000        19.900000      82.000000
#
#        daylight_hours  cloud_amount  ave_wind_speed  max_wind_speed
# count       92.000000     92.000000       92.000000       92.000000
# mean         6.533696      6.735870        3.167391        6.589130
# std          4.456266      3.120812        0.809573        1.418284
# ...

# %%
df.sort_values(by="ave_temperature", ascending=False).head()
# Out:
#          date  ave_temperature  max_temperature  min_temperature  \
# 87  2019/5/27             26.1             32.4             19.9
# 86  2019/5/26             25.2             32.6             18.6
# 85  2019/5/25             24.4             31.9             17.0
# 88  2019/5/28             23.5             28.1             19.1
# 84  2019/5/24             23.1             31.0             16.4
#
#     precipitation  daylight_hours  cloud_amount  ave_wind_speed  \
# 87            NaN            12.6           5.0             3.0
# 86            NaN            12.6           5.3             2.3
# 85            NaN            13.4           0.0             2.7
# 88            1.0             1.2          10.0             5.8
# 84            NaN            13.1           0.3             2.7
#
#     max_wind_speed max_wind_direction
# 87             6.1                 南東
# 86             5.7                南南東
# 85             5.4                 南東
# ...

# %%
df.rename(columns={'降水量':'precipitation'},inplace=True)  # .rename() ... 名前変更
df.head()
# Out:
#        date  ave_temperature  max_temperature  min_temperature  precipitation  \
# 0  2019/3/1              8.8             13.1              6.5            1.5
# 1  2019/3/2             10.3             14.7              6.4            NaN
# 2  2019/3/3              6.5             10.4              4.4           13.5
# 3  2019/3/4              7.3              9.5              5.4           27.5
# 4  2019/3/5              9.6             15.8              4.3            0.5
#
#    daylight_hours  cloud_amount  ave_wind_speed  max_wind_speed  \
# 0             2.4           8.8             2.0             5.0
# 1             9.6           5.3             3.6             7.7
# 2             0.0          10.0             2.7             4.6
# 3             0.0          10.0             3.5             5.5
# 4             9.1           6.0             2.4             6.5
#
#   max_wind_direction
# 0                 北西
# 1                 北西
# 2                北北西
# ...

# %%
df.index = pd.to_datetime(df.index, format='mixed')  
df.index
# Out:
# DatetimeIndex([          '1970-01-01 00:00:00',
#                '1970-01-01 00:00:00.000000001',
#                '1970-01-01 00:00:00.000000002',
#                '1970-01-01 00:00:00.000000003',
#                '1970-01-01 00:00:00.000000004',
#                '1970-01-01 00:00:00.000000005',
#                '1970-01-01 00:00:00.000000006',
#                '1970-01-01 00:00:00.000000007',
#                '1970-01-01 00:00:00.000000008',
#                '1970-01-01 00:00:00.000000009',
#                '1970-01-01 00:00:00.000000010',
#                '1970-01-01 00:00:00.000000011',
#                '1970-01-01 00:00:00.000000012',
#                '1970-01-01 00:00:00.000000013',
#                '1970-01-01 00:00:00.000000014',
#                '1970-01-01 00:00:00.000000015',
#                '1970-01-01 00:00:00.000000016',
#                '1970-01-01 00:00:00.000000017',
#                '1970-01-01 00:00:00.000000018',
#                '1970-01-01 00:00:00.000000019',
# ...

# %%
import numpy as np
import pandas as pd
df = pd.read_csv('weather.csv', sep=',')
df.index = pd.to_datetime(df['date'])
df['month'] = list(pd.Series(df.index).apply(lambda x: x.month))
df['day'] = list(pd.Series(df.index).apply(lambda x: x.day))
df.head()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('weather.csv', sep=',')
plt.style.use('ggplot')
df['max_temperature'].plot()
# Out:
# <Axes: >
